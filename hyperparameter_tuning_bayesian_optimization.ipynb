# %%
import numpy as np
import optuna
from optuna.samplers import TPESampler
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from security_env import SecurityEnv

def objective(trial):
    """
    Objective function for Optuna optimization
    """
    # Define hyperparameter ranges
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
        'n_steps': trial.suggest_categorical('n_steps', [2048, 4096, 8192]),
        'batch_size': trial.suggest_categorical('batch_size', [32, 64, 128]),
        'n_epochs': trial.suggest_categorical('n_epochs', [5, 10, 20]),
        'gamma': trial.suggest_categorical('gamma', [0.95, 0.99, 0.995]),
        'gae_lambda': trial.suggest_categorical('gae_lambda', [0.9, 0.95, 0.98]),
        'clip_range': trial.suggest_categorical('clip_range', [0.1, 0.2, 0.3]),
        'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
        'alpha': trial.suggest_categorical('alpha', [0.3, 0.5, 0.7]),
        'beta': trial.suggest_categorical('beta', [0.3, 0.5, 0.7]),
        's_min': trial.suggest_categorical('s_min', [5.0, 8.0, 10.0])
    }
    
    # Create environment
    env = SecurityEnv(
        rf_model_path="fatigue_model.joblib",
        alpha=params['alpha'],
        beta=params['beta'],
        s_min=params['s_min']
    )
    env = DummyVecEnv([lambda: env])
    
    # Create and train model
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=params['learning_rate'],
        n_steps=params['n_steps'],
        batch_size=params['batch_size'],
        n_epochs=params['n_epochs'],
        gamma=params['gamma'],
        gae_lambda=params['gae_lambda'],
        clip_range=params['clip_range'],
        ent_coef=params['ent_coef'],
        verbose=0
    )
    
    # Train model
    model.learn(total_timesteps=10000)
    
    # Evaluate model
    eval_env = SecurityEnv(
        rf_model_path="fatigue_model.joblib",
        alpha=params['alpha'],
        beta=params['beta'],
        s_min=params['s_min']
    )
    eval_env = DummyVecEnv([lambda: eval_env])
    
    mean_reward, _ = evaluate_model(model, eval_env)
    
    return mean_reward

def run_bayesian_optimization(n_trials=50):
    """
    Run Bayesian Optimization using Optuna
    """
    # Create study
    study = optuna.create_study(
        direction='maximize',
        sampler=TPESampler(seed=42)
    )
    
    # Run optimization
    study.optimize(objective, n_trials=n_trials)
    
    # Print best results
    print("Best trial:")
    trial = study.best_trial
    print("  Value: ", trial.value)
    print("  Params: ")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")
    
    # Save results
    results_df = study.trials_dataframe()
    results_df.to_csv('bayesian_optimization_results.csv', index=False)
    
    return study

def evaluate_model(model, env, n_episodes=5):
    """Evaluate a trained model"""
    rewards = []
    for _ in range(n_episodes):
        obs = env.reset()
        done = False
        episode_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, info = env.step(action)
            episode_reward += reward
        rewards.append(episode_reward)
    return np.mean(rewards), np.std(rewards)

# %%
study = run_bayesian_optimization(n_trials=50)
# Out:
# [I 2025-03-19 02:22:59,001] A new study created in memory with name: no-name-9aa40d30-0c50-46d5-a3fa-97c218b1e983
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 02:28:13,099] Trial 0 finished with value: -40.458885192871094 and parameters: {'learning_rate': 5.6115164153345e-05, 'n_steps': 2048, 'batch_size': 32, 'n_epochs': 5, 'gamma': 0.99, 'gae_lambda': 0.9, 'clip_range': 0.2, 'ent_coef': 7.476312062252303e-05, 'alpha': 0.3, 'beta': 0.7, 's_min': 10.0}. Best is trial 0 with value: -40.458885192871094.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 02:34:33,525] Trial 1 finished with value: 588.4727783203125 and parameters: {'learning_rate': 1.2385137298860926e-05, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.995, 'gae_lambda': 0.95, 'clip_range': 0.1, 'ent_coef': 0.00043664735929796326, 'alpha': 0.5, 'beta': 0.3, 's_min': 5.0}. Best is trial 1 with value: 588.4727783203125.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 02:43:58,474] Trial 2 finished with value: 524.1427612304688 and parameters: {'learning_rate': 1.2315571723666024e-05, 'n_steps': 4096, 'batch_size': 32, 'n_epochs': 20, 'gamma': 0.99, 'gae_lambda': 0.98, 'clip_range': 0.3, 'ent_coef': 1.667761543019792e-05, 'alpha': 0.7, 'beta': 0.3, 's_min': 10.0}. Best is trial 1 with value: 588.4727783203125.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 02:48:42,947] Trial 3 finished with value: -182.86978149414062 and parameters: {'learning_rate': 0.00018841476921545086, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.95, 'clip_range': 0.2, 'ent_coef': 0.0001702741688676439, 'alpha': 0.3, 'beta': 0.7, 's_min': 10.0}. Best is trial 1 with value: 588.4727783203125.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 02:56:21,020] Trial 4 finished with value: 503.7508850097656 and parameters: {'learning_rate': 0.00040489662225846743, 'n_steps': 4096, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.99, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 9.324140221663475e-05, 'alpha': 0.5, 'beta': 0.3, 's_min': 5.0}. Best is trial 1 with value: 588.4727783203125.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:02:35,831] Trial 5 finished with value: -123.05841064453125 and parameters: {'learning_rate': 1.1851515660043103e-05, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.995, 'gae_lambda': 0.95, 'clip_range': 0.2, 'ent_coef': 1.865818136012483e-05, 'alpha': 0.3, 'beta': 0.7, 's_min': 8.0}. Best is trial 1 with value: 588.4727783203125.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:10:10,764] Trial 6 finished with value: 754.7694091796875 and parameters: {'learning_rate': 0.0001951396765593445, 'n_steps': 4096, 'batch_size': 32, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.0007930569433855138, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 6 with value: 754.7694091796875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:16:43,334] Trial 7 finished with value: -64.28242492675781 and parameters: {'learning_rate': 0.0006267702540388485, 'n_steps': 2048, 'batch_size': 32, 'n_epochs': 10, 'gamma': 0.99, 'gae_lambda': 0.95, 'clip_range': 0.1, 'ent_coef': 1.9099601385505377e-05, 'alpha': 0.3, 'beta': 0.3, 's_min': 8.0}. Best is trial 6 with value: 754.7694091796875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:25:25,937] Trial 8 finished with value: -201.6739959716797 and parameters: {'learning_rate': 0.0001424976719890158, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.1, 'ent_coef': 0.00014298589094443974, 'alpha': 0.3, 'beta': 0.5, 's_min': 10.0}. Best is trial 6 with value: 754.7694091796875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:38:08,237] Trial 9 finished with value: -364.04010009765625 and parameters: {'learning_rate': 0.0009552294429449872, 'n_steps': 8192, 'batch_size': 32, 'n_epochs': 20, 'gamma': 0.995, 'gae_lambda': 0.98, 'clip_range': 0.3, 'ent_coef': 0.004677524010176147, 'alpha': 0.5, 'beta': 0.3, 's_min': 10.0}. Best is trial 6 with value: 754.7694091796875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:44:00,641] Trial 10 finished with value: 680.0404052734375 and parameters: {'learning_rate': 4.194601131160366e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.0011746931059660698, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 6 with value: 754.7694091796875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:50:00,612] Trial 11 finished with value: 807.0828857421875 and parameters: {'learning_rate': 5.1544513708209705e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.001326429162132363, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 11 with value: 807.0828857421875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 03:55:52,654] Trial 12 finished with value: 761.4583740234375 and parameters: {'learning_rate': 6.411691587694977e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.0017411879445801653, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 11 with value: 807.0828857421875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:01:52,145] Trial 13 finished with value: 818.6492919921875 and parameters: {'learning_rate': 4.583100027692072e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.004510758226430418, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:07:57,433] Trial 14 finished with value: 764.3817138671875 and parameters: {'learning_rate': 2.793441543946284e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.00867514565549096, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:13:48,311] Trial 15 finished with value: 713.0093383789062 and parameters: {'learning_rate': 2.9652021606646726e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.002753417281226987, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:19:49,601] Trial 16 finished with value: 525.2630004882812 and parameters: {'learning_rate': 9.380073543753393e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 10, 'gamma': 0.95, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.007864978751369765, 'alpha': 0.7, 'beta': 0.5, 's_min': 8.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:26:56,620] Trial 17 finished with value: 810.5730590820312 and parameters: {'learning_rate': 2.3508062239150255e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.3, 'ent_coef': 0.0005214229986704393, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:34:05,673] Trial 18 finished with value: 730.1632690429688 and parameters: {'learning_rate': 2.183549586291765e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.995, 'gae_lambda': 0.9, 'clip_range': 0.1, 'ent_coef': 0.0004174886589853533, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:40:57,634] Trial 19 finished with value: 811.2158813476562 and parameters: {'learning_rate': 2.0431324122021782e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0034771462429724, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:47:51,915] Trial 20 finished with value: 282.86346435546875 and parameters: {'learning_rate': 0.00010082439160065667, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.003266060536250478, 'alpha': 0.5, 'beta': 0.5, 's_min': 8.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:53:09,638] Trial 21 finished with value: 804.3833618164062 and parameters: {'learning_rate': 1.7375422253159303e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0006685326000559692, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 04:58:26,067] Trial 22 finished with value: 752.9696044921875 and parameters: {'learning_rate': 3.2089418146669556e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.004137430738920173, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:03:58,890] Trial 23 finished with value: 813.3419189453125 and parameters: {'learning_rate': 1.7184557860884613e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0022196505143276726, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:09:23,962] Trial 24 finished with value: 806.0691528320312 and parameters: {'learning_rate': 1.7668498408079864e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.00239249685390645, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:14:53,240] Trial 25 finished with value: 681.8416748046875 and parameters: {'learning_rate': 3.668162694244868e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.00557618965742504, 'alpha': 0.7, 'beta': 0.7, 's_min': 5.0}. Best is trial 13 with value: 818.6492919921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:19:46,515] Trial 26 finished with value: 839.2492065429688 and parameters: {'learning_rate': 1.0059889572461039e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.009641052876191708, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:24:56,005] Trial 27 finished with value: 702.293701171875 and parameters: {'learning_rate': 1.0625687119484878e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.00988213445390245, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:30:25,076] Trial 28 finished with value: 534.8653564453125 and parameters: {'learning_rate': 1.5449610542638755e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0017338832160454822, 'alpha': 0.7, 'beta': 0.5, 's_min': 8.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:36:13,733] Trial 29 finished with value: 308.59210205078125 and parameters: {'learning_rate': 7.136569838219769e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.99, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 4.0813676113162666e-05, 'alpha': 0.5, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:40:49,766] Trial 30 finished with value: -114.70722961425781 and parameters: {'learning_rate': 4.530031870999895e-05, 'n_steps': 2048, 'batch_size': 32, 'n_epochs': 10, 'gamma': 0.95, 'gae_lambda': 0.95, 'clip_range': 0.2, 'ent_coef': 0.006390668190124608, 'alpha': 0.3, 'beta': 0.7, 's_min': 10.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:46:03,372] Trial 31 finished with value: 725.7364501953125 and parameters: {'learning_rate': 2.0944593437339408e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.003554579124877185, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:51:44,966] Trial 32 finished with value: 782.0333251953125 and parameters: {'learning_rate': 1.5455914514572943e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0018037497721297168, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 05:57:41,465] Trial 33 finished with value: 807.3698120117188 and parameters: {'learning_rate': 1.3728378396597393e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.005852334977760814, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:03:12,795] Trial 34 finished with value: 603.0367431640625 and parameters: {'learning_rate': 1.0582256238790526e-05, 'n_steps': 8192, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.1, 'ent_coef': 0.0009618534025642526, 'alpha': 0.7, 'beta': 0.7, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:06:46,268] Trial 35 finished with value: 655.22998046875 and parameters: {'learning_rate': 2.264985555151786e-05, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 5, 'gamma': 0.99, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0002360063337068273, 'alpha': 0.7, 'beta': 0.5, 's_min': 5.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:10:44,210] Trial 36 finished with value: 138.92059326171875 and parameters: {'learning_rate': 2.7700403545184454e-05, 'n_steps': 4096, 'batch_size': 128, 'n_epochs': 5, 'gamma': 0.95, 'gae_lambda': 0.95, 'clip_range': 0.2, 'ent_coef': 0.002735471469253119, 'alpha': 0.5, 'beta': 0.5, 's_min': 10.0}. Best is trial 26 with value: 839.2492065429688.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:16:18,684] Trial 37 finished with value: 859.52294921875 and parameters: {'learning_rate': 1.0108877212854842e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.004448235953062759, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:19:32,764] Trial 38 finished with value: 199.18626403808594 and parameters: {'learning_rate': 1.0101294646178192e-05, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.99, 'gae_lambda': 0.95, 'clip_range': 0.1, 'ent_coef': 0.009985041254102475, 'alpha': 0.3, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:23:28,475] Trial 39 finished with value: 605.107421875 and parameters: {'learning_rate': 1.3100880268349401e-05, 'n_steps': 4096, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.005966485790270652, 'alpha': 0.7, 'beta': 0.3, 's_min': 8.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:28:56,796] Trial 40 finished with value: -45.59922790527344 and parameters: {'learning_rate': 1.384721673330075e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.99, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0020959667888406242, 'alpha': 0.3, 'beta': 0.3, 's_min': 10.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:34:52,321] Trial 41 finished with value: 831.33447265625 and parameters: {'learning_rate': 1.8634404404240677e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.00433072771339779, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:40:26,028] Trial 42 finished with value: 688.0626220703125 and parameters: {'learning_rate': 0.00028424451982690224, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.004205870709423129, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:46:09,656] Trial 43 finished with value: 829.4021606445312 and parameters: {'learning_rate': 1.782250844686983e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.005217040122617536, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:51:40,596] Trial 44 finished with value: 846.0369262695312 and parameters: {'learning_rate': 1.1664809492856492e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.0074266515917861585, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 06:57:09,370] Trial 45 finished with value: 555.720458984375 and parameters: {'learning_rate': 1.2525197125827647e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.007268232554308964, 'alpha': 0.5, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 07:02:50,774] Trial 46 finished with value: 800.8704833984375 and parameters: {'learning_rate': 1.0085817358730085e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 1.099985223916306e-05, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 07:08:09,480] Trial 47 finished with value: 831.5238037109375 and parameters: {'learning_rate': 1.233152477559541e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 0.005177244645632934, 'alpha': 0.7, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 07:13:25,191] Trial 48 finished with value: 481.33587646484375 and parameters: {'learning_rate': 1.3796979537911845e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.98, 'clip_range': 0.2, 'ent_coef': 6.691889882728738e-05, 'alpha': 0.7, 'beta': 0.3, 's_min': 10.0}. Best is trial 37 with value: 859.52294921875.
# C:\conda_tmp\ipykernel_29864\2556413631.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-3),
# C:\conda_tmp\ipykernel_29864\2556413631.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-5, 1e-2),
# [I 2025-03-19 07:17:38,613] Trial 49 finished with value: 252.29501342773438 and parameters: {'learning_rate': 1.0806400402898969e-05, 'n_steps': 8192, 'batch_size': 64, 'n_epochs': 20, 'gamma': 0.95, 'gae_lambda': 0.95, 'clip_range': 0.1, 'ent_coef': 0.007686227406914297, 'alpha': 0.3, 'beta': 0.3, 's_min': 5.0}. Best is trial 37 with value: 859.52294921875.
# Best trial:
#   Value:  859.52294921875
#   Params:
#     learning_rate: 1.0108877212854842e-05
#     n_steps: 8192
#     batch_size: 64
#     n_epochs: 20
#     gamma: 0.95
#     gae_lambda: 0.98
#     clip_range: 0.2
#     ent_coef: 0.004448235953062759
#     alpha: 0.7
#     beta: 0.3
#     s_min: 5.0
